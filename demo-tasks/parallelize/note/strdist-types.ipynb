# %% [markdown]
# # setup

# %%
# dependencies
# general
import time
import pandas as pd

# string distance measuring (probably dont want to use all of these the whole time)
import stringdist
import fuzzywuzzy
from fuzzywuzzy import fuzz
import textdistance
import rapidfuzz
import jellyfish
import Levenshtein
import distance

# %%
# support methods
def timedapply(method, a, b):
    s = time.time()
    res = method(a, b)
    e = time.time()
    diff = round(e-s, 8)
    return res, diff


def getmethods():
    return {
    'edit': {
        'td_DamerauLevenshtein': textdistance.damerau_levenshtein.distance, 
        'td_Hamming': textdistance.hamming.distance, 
        'td_Jaro': textdistance.jaro.distance, 
        'td_JaroWinkler': textdistance.jaro_winkler.distance, 
        'td_Levenshtein': textdistance.levenshtein.distance,
        
        'L_Hamming': Levenshtein.hamming,
        'L_Jaro': Levenshtein.jaro,
        'L_JaroWinkler': Levenshtein.jaro_winkler,
        'L_Levenshtein': Levenshtein.distance,
                
        'jf_DamerauLevenshtein': jellyfish.damerau_levenshtein_distance,
        'jf_Jaro': jellyfish.jaro_similarity,
        'jf_Levenshtein': jellyfish.levenshtein_distance,
        
        'd_Jaccard': distance.jaccard,
        'd_Levenshtein': distance.levenshtein,
        
        'fw_Levenshtein': fuzzywuzzy.StringMatcher.distance,
        'rf_Levenshtein': rapidfuzz.distance.Levenshtein.distance,
    },
    'token': {
        'td_Bag': textdistance.bag.distance,
        'td_Cosine': textdistance.cosine.distance,
        'td_Jaccard': textdistance.jaccard.distance,
        
    },
    'sequence': {
        'td_LCSSeq': textdistance.lcsseq.distance,
        'd_LCSSeq': distance.lcsubstrings,
    },
    'compression': {
        'td_EntropyNCD': textdistance.entropy_ncd.distance,
    },
    'phonetic': {
        'td_MRA': textdistance.mra.distance,
    },
    'simple': {
        'td_Identity': textdistance.identity.distance,
    }
}

def applymethods(methods, pairs):
    assert 'line_a' in pairs.columns
    copy = pairs.copy()
    runtime = {}
    for lib, method in methods.items():
        print(f'running calculations for: {lib}')
        s = time.time()
        copy['tup'] = copy.apply(
            lambda row: timedapply(method, row.line_a, row.line_b), axis=1)
        copy[lib] = copy.tup.apply(lambda x: x[0])
        copy[f'{lib}_time'] = copy.tup.apply(lambda x: x[1])
        e = time.time()
        runtime[lib] = e-s
    copy.drop(columns='tup', inplace=True)
    return copy, runtime

# %%
# main
lines = pd.read_parquet("../output/lines.parquet")
pairs = pd.read_parquet("../output/linepairs.parquet")
testpairs = pairs.sample(10)

methods = {f'{disttype}_{libalg}': method
           for disttype, info in getmethods().items() 
           for libalg, method in info.items()}
testpairs, runtime = applymethods(methods, pairs)

# setup results as dataframe for easy review
methodf = pd.DataFrame({'library': methods.keys(), 'method': methods.values()})
runtidf = pd.DataFrame({'library': runtime.keys(), 'time': runtime.values()})
tests = pd.merge(methodf, runtidf, on='library')
# Out:
# running calculations for: edit_td_DamerauLevenshtein
# running calculations for: edit_td_Hamming
# running calculations for: edit_td_Jaro
# running calculations for: edit_td_JaroWinkler
# running calculations for: edit_td_Levenshtein
# running calculations for: edit_L_Hamming
# running calculations for: edit_L_Jaro
# running calculations for: edit_L_JaroWinkler
# running calculations for: edit_L_Levenshtein
# running calculations for: edit_jf_DamerauLevenshtein
# running calculations for: edit_jf_Jaro
# running calculations for: edit_jf_Levenshtein
# running calculations for: edit_d_Jaccard
# running calculations for: edit_d_Levenshtein
# running calculations for: edit_fw_Levenshtein
# running calculations for: edit_rf_Levenshtein
# running calculations for: token_td_Bag
# running calculations for: token_td_Cosine
# running calculations for: token_td_Jaccard
# running calculations for: sequence_td_LCSSeq
# running calculations for: sequence_d_LCSSeq
# running calculations for: compression_td_EntropyNCD
# running calculations for: phonetic_td_MRA
# running calculations for: simple_td_Identity

# %%
#flat = []
#for disttype, info in methods.items():
#    for libalg, method in info.items():
#        lib, alg = libalg.split('_')
#        flat.append((disttype, lib, alg, libalg, method))
#tools = pd.DataFrame(flat, columns=['disttype', 'lib', 'alg', 'colname', 'method'])

# %% [markdown]
# # preview data

# %%
# get 1 random sample for testing
samp = pairs.sample()
a,b = samp.line_a.values[0], samp.line_b.values[0]

# %%
lines.sample(5)
# Out:
#                                                  line  n_alpha  n_digit  \
# 1                     C
# |oEhrN{veaNcK(RdBwlhitONjdJq_       26        0
# 78  okfUvKHhOeUv.KGLeSzKPG hRNwRufG irCnBfpIuMNXAj...      104        0
# 79  TbPAIIphrUPKMlTqhJ;UCD9dRXY PlS4chb jIULICXHbS...       47        3
# 8   EaSeCOBcMPowQbRulRS aKI CoejztMYfSaLiXGM Lcq h...       78        0
# 28                        ChaENXzb1pEA eLlIWMAlQopB+:       23        1
#
#       hashid
# 1   9583bef4
# 78  cce426d4
# 79  dd508488
# 8   7772ee55
# 28  7058a3cd

# %%
pairs.head()
# Out:
#                                               line_a  \
# 0  QFRQAO'og NrbXBtibmCoqxkvHqV RXFoLZV PzEJEvVwh...
# 1  QFRQAO'og NrbXBtibmCoqxkvHqV RXFoLZV PzEJEvVwh...
# 2  QFRQAO'og NrbXBtibmCoqxkvHqV RXFoLZV PzEJEvVwh...
# 3  QFRQAO'og NrbXBtibmCoqxkvHqV RXFoLZV PzEJEvVwh...
# 4  QFRQAO'og NrbXBtibmCoqxkvHqV RXFoLZV PzEJEvVwh...
#
#                                               line_b
# 0  QFRQAO'og NrbXBtibmCoqxkvHqV RXFoLZV PzEJEvVwh...
# 1                    C
# |oEhrN{veaNcK(RdBwlhitONjdJq_
# 2  FbAbnjfgNuIzyqjivrDea4S xKLFPzCigoMkN CRKHtzP ...
# 3                              keqULtDbxzda.eF^pIUH]
# 4                           XJT2spY^PznKWu#gd(wdYJQ-

# %%
a
# Out:
# 'TC fXvckzNFVnd)KdNJXx\x0ba dcoEMSP+'

# %%
b
# Out:
# 'sqPOjxcRj~pHW}HGOFy HsLyruaJaM]DpEySup=OOzYAW PVQIWptfWcmqWUOk GDomqGifeTFVRhc T)'

# %% [markdown]
# # array of tests

# %%
testpairs.sample().T
# Out:
#                                                                               7446
# line_a                               TjTvLjItNHkIPNqYxuzFpac TavN qyK#b QqKHRCXWi^
# line_b                           NDTMCkmeWt hPDCSyYgb MjjtbQ oLdOKDDlFnBb lVGeN...
# edit_td_DamerauLevenshtein                                                     117
# edit_td_DamerauLevenshtein_time                                           0.000002
# edit_td_Hamming                                                                132
# edit_td_Hamming_time                                                      0.000006
# edit_td_Jaro                                                              0.506278
# edit_td_Jaro_time                                                         0.000003
# edit_td_JaroWinkler                                                       0.506278
# edit_td_JaroWinkler_time                                                  0.000002
# edit_td_Levenshtein                                                            117
# edit_td_Levenshtein_time                                                  0.000002
# edit_L_Hamming                                                                 132
# edit_L_Hamming_time                                                            0.0
# edit_L_Jaro                                                               0.493722
# edit_L_Jaro_time                                                          0.000002
# edit_L_JaroWinkler                                                        0.493722
# edit_L_JaroWinkler_time                                                   0.000002
# edit_L_Levenshtein                                                             117
# edit_L_Levenshtein_time                                                   0.000001
# edit_jf_DamerauLevenshtein                                                     117
# edit_jf_DamerauLevenshtein_time                                           0.000073
# edit_jf_Jaro                                                              0.493722
# edit_jf_Jaro_time                                                         0.000013
# edit_jf_Levenshtein                                                            117
# edit_jf_Levenshtein_time                                                  0.000037
# edit_d_Jaccard                                                            0.534483
# edit_d_Jaccard_time                                                       0.000004
# edit_d_Levenshtein                                                             117
# edit_d_Levenshtein_time                                                   0.001378
# edit_fw_Levenshtein                                                            117
# edit_fw_Levenshtein_time                                                  0.000001
# edit_rf_Levenshtein                                                            117
# edit_rf_Levenshtein_time                                                  0.000001
# token_td_Bag                                                                    98
# token_td_Bag_time                                                         0.000026
# token_td_Cosine                                                             0.5364
# token_td_Cosine_time                                                      0.000014
# token_td_Jaccard                                                          0.748252
# token_td_Jaccard_time                                                     0.000023
# sequence_td_LCSSeq                                                             115
# sequence_td_LCSSeq_time                                                   0.002541
# sequence_d_LCSSeq                                                     { Q,  q, b }
# sequence_d_LCSSeq_time                                                     0.00043
# compression_td_EntropyNCD                                                 0.120596
# compression_td_EntropyNCD_time                                            0.000041
# phonetic_td_MRA                                                                  4
# phonetic_td_MRA_time                                                      0.000039
# simple_td_Identity                                                               1
# simple_td_Identity_time                                                        0.0

# %%
testpairs[['line_a', 'line_b', 'edit_L_Levenshtein', 'edit_L_Levenshtein_time']
         ].sort_values('edit_L_Levenshtein_time')
# Out:
#                                                  line_a  \
# 9999  wQMVZ VbMSX:q YTqYDBY vBAlRS@hDHhKYMHAvx cHkEQ...
# 2623  TDs'F\tablq#gWzQtkrW dB aWuxVNBGjuLydbuZI GyTs...
# 2626  TDs'F\tablq#gWzQtkrW dB aWuxVNBGjuLydbuZI GyTs...
# 2628  TDs'F\tablq#gWzQtkrW dB aWuxVNBGjuLydbuZI GyTs...
# 6901  n wpC,lo8dlqmSD>EqdXE CoFcXIBedZnhnhT EHEgBWLe...
# ...                                                 ...
# 5002  oAUsQLdLpbZTA~vow IHEzbaA[PMGyvKsqHFNGHREHaLK ...
# 8534  gROHJSbDPNtqszclSNBnULlz ccaGQgxn KqoLvMeSbHmX...
# 6602  cAAQArCFdvRmcXgfZq?tsDqEo ufcCcWx rdCWiBhSOruc...
# 8502  gROHJSbDPNtqszclSNBnULlz ccaGQgxn KqoLvMeSbHmX...
# 0     QFRQAO'og NrbXBtibmCoqxkvHqV RXFoLZV PzEJEvVwh...
#
#                                                  line_b  edit_L_Levenshtein  \
# 9999  wQMVZ VbMSX:q YTqYDBY vBAlRS@hDHhKYMHAvx cHkEQ...                   0
# 2623                   TC fXvckzNFVnd)KdNJXx
# a dcoEMSP+                  91
# 2626  TDs'F\tablq#gWzQtkrW dB aWuxVNBGjuLydbuZI GyTs...                   0
# 2628                        ChaENXzb1pEA eLlIWMAlQopB+:                  93
# 6901                    C
# |oEhrN{veaNcK(RdBwlhitONjdJq_                 103
# ...                                                 ...                 ...
# 5002  FbAbnjfgNuIzyqjivrDea4S xKLFPzCigoMkN CRKHtzP ...                 155
# 8534  RgJwLq,acKIGhsARgDmdDJ oKQLDg XnNxVmsIXGhqHDhg...                 153
# 6602  FbAbnjfgNuIzyqjivrDea4S xKLFPzCigoMkN CRKHtzP ...                 155
# 8502  FbAbnjfgNuIzyqjivrDea4S xKLFPzCigoMkN CRKHtzP ...                 160
# 0     QFRQAO'og NrbXBtibmCoqxkvHqV RXFoLZV PzEJEvVwh...                   0
#
#       edit_L_Levenshtein_time
# 9999                 0.000000
# 2623                 0.000000
# 2626                 0.000000
# 2628                 0.000000
# 6901                 0.000000
# ...                       ...
# 5002                 0.000003
# 8534                 0.000003
# 6602                 0.000003
# 8502                 0.000003
# 0                    0.000003
#
# [10000 rows x 4 columns]

# %%
tests.sort_values('time')
# Out:
#                        library  \
# 5               edit_L_Hamming
# 8           edit_L_Levenshtein
# 7           edit_L_JaroWinkler
# 15         edit_rf_Levenshtein
# 23          simple_td_Identity
# 6                  edit_L_Jaro
# 14         edit_fw_Levenshtein
# 0   edit_td_DamerauLevenshtein
# 4          edit_td_Levenshtein
# 3          edit_td_JaroWinkler
# 2                 edit_td_Jaro
# 12              edit_d_Jaccard
# 1              edit_td_Hamming
# 10                edit_jf_Jaro
# 17             token_td_Cosine
# 18            token_td_Jaccard
# 16                token_td_Bag
# 22             phonetic_td_MRA
# 21   compression_td_EntropyNCD
# 11         edit_jf_Levenshtein
# 9   edit_jf_DamerauLevenshtein
# 20           sequence_d_LCSSeq
# 13          edit_d_Levenshtein
# 19          sequence_td_LCSSeq
#
#                                                method       time
# 5                   <function hamming at 0x14fe9c4a0>   0.058019
# 8                  <function distance at 0x105f42de0>   0.066317
# 7              <function jaro_winkler at 0x14ff5cae0>   0.067896
# 15               <cyfunction distance at 0x14fecbc60>   0.068231
# 23  <bound method BaseSimilarity.distance of Ident...   0.068679
# 6                      <function jaro at 0x14ff5cc20>   0.068830
# 14                 <function distance at 0x105f42de0>   0.069656
# 0   <bound method Base.distance of DamerauLevensht...   0.079334
# 4   <bound method Base.distance of Levenshtein({'q...   0.079979
# 3   <bound method BaseSimilarity.distance of JaroW...   0.085653
# 2   <bound method BaseSimilarity.distance of Jaro(...   0.085876
# 12                  <function jaccard at 0x14ffe0c20>   0.104825
# 1   <bound method Base.distance of Hamming({'qval'...   0.111107
# 10                <built-in function jaro_similarity>   0.207690
# 17  <bound method BaseSimilarity.distance of Cosin...   0.243419
# 18  <bound method BaseSimilarity.distance of Jacca...   0.301345
# 16  <bound method Base.distance of Bag({'qval': 1,...   0.358334
# 22  <bound method BaseSimilarity.distance of MRA({...   0.429930
# 21  <bound method Base.distance of EntropyNCD({'qv...   0.451270
# 11           <built-in function levenshtein_distance>   0.474168
# 9    <built-in function damerau_levenshtein_distance>   0.885709
# 20             <function lcsubstrings at 0x14ffe0860>   4.873104
# 13              <function levenshtein at 0x14ffe09a0>  15.061804
# 19  <bound method BaseSimilarity.distance of LCSSe...  27.198128
