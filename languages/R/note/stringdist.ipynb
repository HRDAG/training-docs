# %%
# dependencies
library(arrow)
library(stringdist)
# Out:
# Attaching package: ‘arrow’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp

# %%
# support methods
similarity <- function(string1, string2, method, ...) {
    1 - stringdist(string1, string2, method = method, nthread = 1, ...)
}

Ratio <- function(string_1, string_2) {
    1 - stringdist(string1, string2, method = "lv", nthread = 1, ...)
}

Partial_ratio <- function(string_1, string_2) {
    1 - stringdist(string1, string2, method = "lv", nthread = 1, ...)
}

Token_sort_ratio <- function(string_1, string_2) {
    1 - stringdist(string1, string2, method = "lv", nthread = 1, ...)
}

QRatio <- function(string_1, string_2) {
    1 - stringdist(string1, string2, method = "lv", nthread = 1, ...)
}

UQRatio <- function(string_1, string_2) {
    1 - stringdist(string1, string2, method = "lv", nthread = 1, ...)
}

WRatio <- function(string_1, string_2) {
    1 - stringdist(string1, string2, method = "lv", nthread = 1, ...)
}

UWRatio <- function(string_1, string_2) {
    1 - stringdist(string1, string2, method = "lv", nthread = 1, ...)
}

# %%
# main
methods <- c("osa", "lv", "dl", "hamming", "lcs", "qgram", "cosine", "jaccard", "jw")
pairs <- read_parquet("output/test_pairs.parquet")

# 1. col for built-in adist
# 2. col = similarity(col) for col in methods
# 3. col for each of fuzz (Ratio, Partial_ratio, etc)
#class_feats <- pairs %>%
#    inner_join(processed, by = c("string_1" = "string")) %>%
#    inner_join(processed, by = c("string_2" = "string"),
#               suffix = c("_1", "_2")) %>%
#    mutate(so_nombre = similarity(so_nombre_1, so_nombre_2, method = "jaccard"))

# %%
pairs
# Out:
#    string_1 string_2
# 1  alpha    alpha
# 2  alpha    alba
# 3  alpha    alvarez
# 4  alpha    bravo
# 5  alpha    jose
# 6  alpha    jóse
# 7  alpha    j0se
# 8  alpha    iose
# 9  alba     alpha
# 10 alba     alba
# 11 alba     alvarez
# 12 alba     bravo
# 13 alba     jose
# 14 alba     jóse
# 15 alba     j0se
# 16 alba     iose
# 17 alvarez  alpha
# 18 alvarez  alba
# 19 alvarez  alvarez
# 20 alvarez  bravo
# 21 alvarez  jose
# 22 alvarez  jóse
# 23 alvarez  j0se
# 24 alvarez  iose
# 25 bravo    alpha
# 26 bravo    alba
# 27 bravo    alvarez
# 28 bravo    bravo
# 29 bravo    jose
# 30 bravo    jóse
# ⋮  ⋮        ⋮
# 35 jose     alvarez
# 36 jose     bravo
# 37 jose     jose
# 38 jose     jóse
# 39 jose     j0se
# 40 jose     iose
# 41 jóse     alpha
# 42 jóse     alba
# 43 jóse     alvarez
# 44 jóse     bravo
# 45 jóse     jose
# 46 jóse     jóse
# 47 jóse     j0se
# 48 jóse     iose
# 49 j0se     alpha
# 50 j0se     alba
# 51 j0se     alvarez
# 52 j0se     bravo
# ...

# %%
typeof(tests)
# Out:
# [1] "character"

# %% [markdown]
# `weight`: the penalty for deletion, insertion, substitution and transposition, in that order. When method='lv', the penalty for transposition is ignored
# `maxDist`: Elements in x will not be matched with elements of table if their distance is larger than maxDist. Note that the maximum distance between strings depends on the method: it should always be specified.

# %%
string_1 = tests[1]
string_2 = tests[2]

stringdist(string1, string2, method = "lv",
# Out:
# Error in parse(text = x, srcfile = src): <text>:5:0: unexpected end of input
# 3:
# 4: stringdist(string1, string2, method=
#   ^
# Traceback:

# %%
?stringdist
